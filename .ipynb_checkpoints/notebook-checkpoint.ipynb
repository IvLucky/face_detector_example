# %% [markdown]
# # Face detector
#
# Выполнил: студент группы А-14м-16 Мигаль Иван.
#
# Описание:
#
# Решение задачи распознавания лиц с помощью opencv.
# * [Ссылка на сайт OpenCV](https://docs.opencv.org/)
# * [Ссылка на сайт matplotlib](https://matplotlib.org/)

# %%
# %matplotlib inline
import cv2
import os
import matplotlib
from matplotlib import pyplot as plt
import sys

print('Версия python3:', sys.version)
print('Версия OpenCV:', cv2.__version__)
print('Версия matplotlib:', matplotlib.__version__)
print('Абсолютный путь к папке python3:', sys.executable)
# Out:
# Версия python3: 3.5.2 |Anaconda custom (64-bit)| (default, Jul  2 2016, 17:53:06)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# Версия OpenCV: 3.2.0
# Версия matplotlib: 1.5.3
# Абсолютный путь к папке python3: /home/ivmig/anaconda3/bin/python

# %% [markdown]
# Для определения лиц используем каскады Хаара.
#
# Ссылки на дополнительную информацию:
# * [Использование каскада Хаара для сравнения изображений](https://habrahabr.ru/post/198338/)
#
# * [Работа каскада Хаара в OpenCV в картинках: теория и практика](https://habrahabr.ru/company/recognitor/blog/228195/)
#
# * [Признаки Хаара](https://ru.wikipedia.org/wiki/%D0%9F%D1%80%D0%B8%D0%B7%D0%BD%D0%B0%D0%BA%D0%B8_%D0%A5%D0%B0%D0%B0%D1%80%D0%B0)

# %%
cascPath = "haarcascade_frontalface_alt.xml"
# Загружаем каскады
faceCascade = cv2.CascadeClassifier(cascPath)

# %%
# Читаем изображение
imagePath = os.getcwd() + '/img/abba.png'
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# Определяем лица на изображении
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)

# %%
print("Found {0} faces!".format(len(faces)))

# Выводим картинку с выделенными лицами
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

plt.imshow(image);
# Out:
# Found 4 faces!
