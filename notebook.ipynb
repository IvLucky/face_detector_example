# %% [markdown]
# # Face detector
#
# Описание:
#
# Решение задачи распознавания лиц с помощью opencv.
#
# [Ссылка на сайт opencv](https://docs.opencv.org/)
# [Ссылка на сайт matplotlib](https://matplotlib.org/)

# %%
# %matplotlib inline
import cv2
import os
import matplotlib
from matplotlib import pyplot as plt
import sys

sys.version, cv2.__version__, matplotlib.__version__, sys.executable
# Out:
# ('3.5.2 |Anaconda custom (64-bit)| (default, Jul  2 2016, 17:53:06) \n[GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]',
#  '3.2.0',
#  '1.5.3',
#  '/home/ivmig/anaconda3/bin/python')

# %%
cascPath = "haarcascade_frontalface_default.xml"
# Загружаем каскады
faceCascade = cv2.CascadeClassifier(cascPath)

# %%
# Read the image
imagePath = os.getcwd() + '/img/abba.png'
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)

# %%
print("Found {0} faces!".format(len(faces)))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

plt.imshow(image);
# Out:
# Found 4 faces!
